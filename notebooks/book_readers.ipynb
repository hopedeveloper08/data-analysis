# %% [markdown]
# # بررسی میانگین امتیاز انتشارات و تعداد کتاب های نویسنده براساس تعداد صفحه

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # خواندن داده ها

# %%
df = pd.read_csv('../data/goodreads/books_db.csv')
df.head()
# Out:
#    bookID                                              title  average_rating  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...            4.57
# 1       2  Harry Potter and the Order of the Phoenix (Har...            4.49
# 2       4  Harry Potter and the Chamber of Secrets (Harry...            4.42
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...            4.56
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...            4.78
#
#          isbn        isbn13  num_pages  ratings_count  text_reviews_count  \
# 0   439785960  9.780440e+12        652        2095690               27591
# 1   439358078  9.780440e+12        870        2153167               29221
# 2   439554896  9.780440e+12        352           6333                 244
# 3  043965548X  9.780440e+12        435        2339585               36325
# 4   439682584  9.780440e+12       2690          41428                 164
#
#   publication_date  author_id  lang_id  publisher_id
# 0        9/16/2006          0        0             0
# 1         9/1/2004          0        0             0
# 2        11/1/2003          0        0             1
# 3         5/1/2004          0        0             0
# 4        9/13/2004          0        0             1

# %% [markdown]
# # ادغام داده های مستقل به دیتافریم اصلی

# %%
authors = pd.read_csv('../data/goodreads/authors.csv')
language = pd.read_csv('../data/goodreads/language.csv')
publisher = pd.read_csv('../data/goodreads/publisher.csv')
authors.rename(columns={'name': 'author'}, inplace=True)
language.rename(columns={'code': 'lang'}, inplace=True)
publisher.rename(columns={'name': 'publisher'}, inplace=True)

# %%
df = df.merge(authors, left_on='author_id', right_index=True)
df = df.merge(language, left_on='lang_id', right_index=True)
df = df.merge(publisher, left_on='publisher_id', right_index=True)
df.drop(columns=['author_id', 'lang_id', 'publisher_id'], inplace=True)
del authors, language, publisher
df.head()
# Out:
#    bookID                                              title  average_rating  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...            4.57
# 1       2  Harry Potter and the Order of the Phoenix (Har...            4.49
# 2       4  Harry Potter and the Chamber of Secrets (Harry...            4.42
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...            4.56
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...            4.78
#
#          isbn        isbn13  num_pages  ratings_count  text_reviews_count  \
# 0   439785960  9.780440e+12        652        2095690               27591
# 1   439358078  9.780440e+12        870        2153167               29221
# 2   439554896  9.780440e+12        352           6333                 244
# 3  043965548X  9.780440e+12        435        2339585               36325
# 4   439682584  9.780440e+12       2690          41428                 164
#
#   publication_date        author lang        publisher
# 0        9/16/2006  J.K. Rowling  eng  Scholastic Inc.
# 1         9/1/2004  J.K. Rowling  eng  Scholastic Inc.
# 2        11/1/2003  J.K. Rowling  eng       Scholastic
# 3         5/1/2004  J.K. Rowling  eng  Scholastic Inc.
# 4        9/13/2004  J.K. Rowling  eng       Scholastic

# %% [markdown]
# # میانگین امتیاز کتاب های یک انشارات

# %%
publisher_rating = df.groupby('publisher')['average_rating'].mean().sort_values(ascending=False)
pd.DataFrame(publisher_rating).head()
# Out:
#                      average_rating
# publisher
# Y Lolfa                         5.0
# Academica Press                 5.0
# T&T Clark Int'l                 5.0
# Raintree                        5.0
# Boosey & Hawkes Inc             5.0

# %% [markdown]
# # تعداد کتاب های هر نویسنده بر اساس دسته ی تعداد صفحات

# %%
p = df['num_pages']
df['num_pages_grp'] = np.select(
    [
        p < 250,
        (250 <= p) & (p < 500),
        (500 <= p) & (p < 750),
        (750 <= p) & (p < 1000),
        1000 <= p
    ],
    [
        '<250',
        '250-499',
        '500-749',
        '750-999',
        '>=1000',
    ],
    default=''
)
df.head()
# Out:
#    bookID                                              title  average_rating  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...            4.57
# 1       2  Harry Potter and the Order of the Phoenix (Har...            4.49
# 2       4  Harry Potter and the Chamber of Secrets (Harry...            4.42
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...            4.56
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...            4.78
#
#          isbn        isbn13  num_pages  ratings_count  text_reviews_count  \
# 0   439785960  9.780440e+12        652        2095690               27591
# 1   439358078  9.780440e+12        870        2153167               29221
# 2   439554896  9.780440e+12        352           6333                 244
# 3  043965548X  9.780440e+12        435        2339585               36325
# 4   439682584  9.780440e+12       2690          41428                 164
#
#   publication_date        author lang        publisher num_pages_grp
# 0        9/16/2006  J.K. Rowling  eng  Scholastic Inc.       500-749
# 1         9/1/2004  J.K. Rowling  eng  Scholastic Inc.       750-999
# 2        11/1/2003  J.K. Rowling  eng       Scholastic       250-499
# 3         5/1/2004  J.K. Rowling  eng  Scholastic Inc.       250-499
# 4        9/13/2004  J.K. Rowling  eng       Scholastic        >=1000

# %%
author_page = df.groupby(['author', 'num_pages_grp']).size()
pd.DataFrame(author_page).head()
# Out:
#                                0
# author          num_pages_grp
# A.B. Yehoshua   250-499        1
#                 500-749        1
# A.D.P. Briggs   250-499        1
# A.E. Cunningham <250           1
# A.J. Jacobs     250-499        1
